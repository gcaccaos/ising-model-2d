# %%
# Importacao de pacotes
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from ipywidgets import widgets
from ising2d import *

np.seterr(divide = 'ignore', invalid = 'ignore'); # ignora warnings sobre divisao por zero (no calculo da probabilidade de flipar os spins para T = 0)

# %%
# Inicializacao das variaveis da simulacao
L = 10 # tamanho do array de spins
N = int(1e3) # numero de varreduras
J = 1 # constante de interacao entre os spins
h = 0 # constante de interacao do spin com o campo magnetico externo
kB = 1 # constante de Boltzmann

Tmin = 0 # temperatura minima (bem proxima de zero)
Tmax = 5 # temperatura maxima
DeltaT = 0.2 # passo das temperaturas
vecT = np.arange(Tmin, Tmax + DeltaT, DeltaT) # vetor de temperaturas
NT = len(vecT) # tamanho do vetor de temperaturas
Beta = 1/(kB*vecT) # vetor de temperatura inversa

m = np.zeros(NT) # array de magnetizacao media de cada elemento para todas as temperaturas

# %%
# Simulacao para cada temperatura
fig = plt.figure()
# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for T, k in zip(vecT, range(NT)):
    spins = metropolis(L, N, T, J, h, kB) # simula a configuracao de spins (N vezes)
    
    # Captura o frame da ultima varredura 
    im = plt.imshow(spins[:, :, N - 1], animated = True)
    ims.append([im])
    
    # Calcula magnetizacao media das N varreduras
    m[k] = spins.sum()/(L*L*N)

# %%
# Animacao da ultima varredura para cada temperatura
ani = animation.ArtistAnimation(fig, ims, interval = 200, blit = True,
                                repeat_delay = 1000)
ani.save("movie.mp4")

# %%
plt.plot(vecT, m, '-o')
plt.xlabel('T')
plt.ylabel('m')
plt.show()

# %%
# magnetizacao media em cada iteracao
plt.plot(spins.sum(axis = 0).sum(axis = 0)/(L*L))
plt.xlim(0, 1000)
plt.show()
plt.hist(spins.sum(axis = 0).sum(axis = 0)/(L*L))
plt.show()
